# %%
import pandas as pd
import pickle as pkl
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.max_rows',4000)

# %%
df = pd.read_csv('../data/irt.csv')

# %%
df.drop(['Unnamed: 0', 'id', 'agency'], axis=1, inplace=True)

# %%
df
# Out:
#                   date                                        subject  \
# 0      9/30/2021 22:26                 Update : BX   4 Train   Delays
# 1      9/30/2021 22:13                          BX   4 Train   Delays
# 2      9/30/2021 21:34                 Update : BX   2 Train   Delays
# 3      9/30/2021 21:28                          BX   2 Train   Delays
# 4      9/30/2021 19:14                 Update : BX   2 Train   Delays
# ...                ...                                            ...
# 67478    1/1/2010 9:55     MANH   2 & 3 trains   Police Investigation
# 67479    1/1/2010 0:56  UPDATED : BX   4 Train   Police Investigation
# 67480    1/1/2010 0:49  UPDATED : BX   4 Train   Police Investigation
# 67481    1/1/2010 0:35  UPDATED : BX   4 Train   Police Investigation
# 67482    1/1/2010 0:26            BX   4 Train   Police Investigation
#
#                                                                                                                                       message
# 0                      4 trains are proceeding in both directions with delays after EMS assisted someone in need of medical help at Woodlawn.
# 1       4 trains are delayed entering / leaving Woodlawn while we request EMS assistance for someone in need of medical help at that station.
# 2                               2 trains are proceeding with delays after our crews moved a train that had its brakes activated at Nereid Av.
# 3                       2 trains are delayed in both directions while our crews investigate why a train's brakes were activated at Nereid Av.
# 4                                     Southbound 2 trains are proceeding after we moved a train that had its brakes activated at Allerton Av.
# ...                                                                                                                                       ...
# 67478  Selected BK-bound 2 & 3 trains terminate at various stations. Due to nypd investigation at Houston St. Visit www.mta.info for details.
# 67479                                                                                       4 train service has resumed with residual delays.
# 67480                 BK-bound. 4 train express Burnside Av to 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
# 67481         Both directions. 4 train susp btwn Burnside Av & 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
# 67482       BK-bound. 4 train via express track Burnside Av to 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
#
# [67483 rows x 3 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
len(wc)
# Out:
# 956

# %%
df2 = df.loc[df['subject'].str.contains('2')]

# %%
df2['date']
# Out:
# 2       2021-09-30 21:34:00
# 3       2021-09-30 21:28:00
# 4       2021-09-30 19:14:00
# 5       2021-09-30 19:10:00
# 7       2021-09-30 18:48:00
#                 ...
# 67467   2010-01-06 08:45:00
# 67468   2010-01-06 07:41:00
# 67471   2010-01-05 18:08:00
# 67477   2010-01-01 10:56:00
# 67478   2010-01-01 09:55:00
# Name: date, Length: 22563, dtype: datetime64[ns]

# %%
df_irt = df.loc[~df['subject'].str.contains('2')]

# %%
df_irt
# Out:
#                      date                                        subject  \
# 0     2021-09-30 22:26:00                 Update : BX   4 Train   Delays
# 1     2021-09-30 22:13:00                          BX   4 Train   Delays
# 6     2021-09-30 18:50:00                Update : QNS   7 Train   Delays
# 8     2021-09-30 18:40:00                         QNS   7 Train   Delays
# 13    2021-09-30 17:42:00           MANH   4   5   and 6 Trains   Delays
# ...                   ...                                            ...
# 67476 2010-01-02 08:28:00              QNS   7 train   Track Maintenance
# 67479 2010-01-01 00:56:00  UPDATED : BX   4 Train   Police Investigation
# 67480 2010-01-01 00:49:00  UPDATED : BX   4 Train   Police Investigation
# 67481 2010-01-01 00:35:00  UPDATED : BX   4 Train   Police Investigation
# 67482 2010-01-01 00:26:00            BX   4 Train   Police Investigation
#
#                                                                                                                                                                                                                                                              message
# 0                                                                                                                                             4 trains are proceeding in both directions with delays after EMS assisted someone in need of medical help at Woodlawn.
# 1                                                                                                                              4 trains are delayed entering / leaving Woodlawn while we request EMS assistance for someone in need of medical help at that station.
# 6                                                                                                                                                          34 St-bound 7 trains are proceeding with delays following an earlier NYPD investigation at qnsboro Plaza.
# 8                                                                                                                                                             34 St-bound 7 trains are holding in stations in qns because of an NYPD investigation at qnsboro Plaza.
# 13     4 5 6 trains are running with extensive delays after our crews performed urgent track maintenance at Grand Central-42 St.\n\nAs an alternative for service to the bx use 1 2 3 B D trains. \n\nAs an alternaitve for service to Brooklyn use A B C Q service.
# ...                                                                                                                                                                                                                                                              ...
# 67476                                                                                                                             Times Sq-bound 7 trains operating on normal route. Due to cancellation of track maintenance. Visit www.mta.info for more details.
# 67479                                                                                                                                                                                                              4 train service has resumed with residual delays.
# 67480                                                                                                                                        BK-bound. 4 train express Burnside Av to 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
# 67481                                                                                                                                Both directions. 4 train susp btwn Burnside Av & 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
# 67482                                                                                                                              BK-bound. 4 train via express track Burnside Av to 125 St. Due to a nypd investigation at 161 St. Visit www.mta.info for details.
#
# [44920 rows x 3 columns]

# %%
df2.to_csv('df2.csv')

# %%
df_irt.to_csv('df_irt.csv')

# %%
wc = pd.Series(' '.join(df2.subject).split()).value_counts()
wc
# Out:
# 2                   22553
# Trains              18246
# and                 13756
# :                   13126
# 3                   11419
# UPDATED             11072
# MANH                11007
# 5                    6087
# BX                   5840
# BK                   5334
# Problems             4737
# &                    4291
# 1                    3423
# Signal               3131
# Delays               2803
# Mechanical           2284
# Train                2155
# Update               1958
# trains               1948
# 4                    1744
# Track                1653
# Sick                 1644
# Maintenance          1482
# NYPD                 1422
# Activity             1326
# Switch               1169
# problems             1075
# Passenger             993
# Customer              941
# Investigation         923
# Rail                  848
# Bx                    836
# Medical               820
# Assistance            802
# Brakes                660
# Condition             591
# Problem               585
# Activated             559
# train                 557
# FDNY                  549
# Police                523
# Person                500
# to                    420
# Local                 417
# Express               415
# on                    323
# Unauthorized          322
# Multiple              321
# Impacts               314
# Tracks                284
# Replacement           278
# problem               276
# Weather               274
# activity              244
# Earlier               238
# assistance            232
# Incident              229
# Disruptive            212
# investigation         209
# Service               207
# the                   203
# Struck                197
# signal                186
# customer              183
# Cold                  176
# Plan                  175
# Some                  170
# condition             168
# maintenance           165
# /                     164
# EMS                   164
# of                    161
# Work                  148
# by                    143
# Malfunction           140
# Injured               137
# 6                     134
# medical               133
# Door                  127
# Smoke                 126
# -                     125
# NYCT                  123
# Part                  110
# Suspended             110
# Temporary             108
# passenger             108
# Help                  102
# Unruly                102
# On                    100
# Speeds                 96
# Slow                   96
# Car                    88
# mechanical             86
# tracks                 79
# Debris                 78
# Injury                 77
# activated              74
# By                     73
# a                      69
# Stations               68
# Skipped                68
# Correction             64
# nypd                   64
# Power                  64
# Dirty                  61
# Someone                59
# in                     58
# Inclement              56
# Conditions             54
# Loss                   52
# person                 50
# trouble                49
# Equipment              49
# track                  48
# Water                  47
# bk                     46
# Removed                44
# rail                   43
# From                   42
# requiring              42
# Essential              41
# NYC                    40
# Broken                 40
# Activation             40
# Planned                40
# Brake                  39
# Ongoing                39
# Need                   37
# St                     37
# struck                 37
# work                   36
# Limited                35
# Countdown              35
# A                      34
# Reroutes               34
# Clocks                 33
# switch                 33
# Trains.                32
# bound                  31
# The                    31
# smoke                  30
# Problems.              29
# CORRECTION             29
# Change                 27
# Emergency              27
# Passengers             26
# Rerouted               26
# UPDATE                 25
# Maintenace             24
# Repairs                23
# Station                23
# Urgent                 22
# Fire                   22
# need                   22
# Stalled                22
# Soiled                 22
# 7                      22
# road                   21
# Unsanitary             20
# Manh                   20
# Repair                 19
# Main                   19
# In                     19
# service                19
# at                     19
# from                   18
# power                  18
# Break                  18
# sick                   18
# Of                     17
# Vandalized             17
# Street                 17
# Building               17
# with                   17
# Weekday                16
# Crowd                  16
# lines                  16
# Transit                16
# Shuttle                15
# Marathon               15
# parade                 15
# Attention              14
# Line                   14
# an                     14
# Platform               14
# Con                    14
# Related                14
# Elevator               14
# Winter                 14
# Cancellation           13
# Speed                  13
# QNS                    13
# Restriction            13
# Crews                  13
# manh                   12
# Maintenence            12
# Maintenance.           12
# Level                  12
# Congestion             12
# Unstable               12
# Derailment             12
# With                   12
# Customer.              11
# West                   11
# Unconscious            11
# structural             11
# Lines                  11
# replacement            11
# Indian                 11
# MANH.                  11
# Available              11
# Day                    11
# loss                   10
# Ed                     10
# Issue                  10
# Activated.             10
# Fallen                 10
# Underground            10
# Storm                  10
# shuttle                10
# System                 10
# Preparations            9
# Longer                  9
# Structural              9
# Weeknight               9
# debris                  9
# equipment               9
# BX.                     9
# Moving                  9
# Restoration             9
# Inspection              9
# Replacement.            9
# C                       9
# BK.                     9
# Activiated              9
# Interior                9
# Outage                  8
# Network                 8
# Deliver                 8
# removed                 8
# Hanging                 8
# Activty                 8
# Prolems                 8
# Crane                   8
# for                     8
# All                     8
# Assaulted               8
# D                       8
# Boroughs                8
# Tree                    8
# weather                 8
# Elevators               8
# Brooklyn                7
# Gap                     7
# Half                    7
# Disabled                7
# 125                     7
# Collapse                7
# Bus                     7
# injured                 7
# Employee                7
# brakes                  7
# Changes                 7
# Mechancial              7
# Failure                 7
# car                     7
# Maintnance              6
# Communication           6
# Impending               6
# Dog                     6
# delays                  6
# off                     6
# planned                 6
# Vandalism               6
# MEchanical              6
# Being                   6
# Cleaning                6
# Dropping                6
# Manhole                 6
# Requiring               6
# Shopping                6
# s                       6
# Test                    6
# Roand                   6
# Cart                    6
# correction              6
# Trouble                 6
# ALL                     5
# Weekend                 5
# incident                5
# Isolating               5
# Subway                  5
# BOROUGHS                5
# Customers               5
# Out                     5
# Isolated                5
# 42                      5
# Time                    5
# collapse                5
# Residual                5
# buses                   5
# TRAINS                  5
# unauthorized            5
# X                       4
# times                   4
# Wait                    4
# Eve                     4
# attention               4
# Assistance.             4
# Times                   4
# Public                  4
# Dust                    4
# Third                   4
# Nevins                  4
# Houston                 4
# cusotmer                4
# repairs                 4
# Needs                   4
# New                     4
# Inspections             4
# Remove                  4
# MAHN                    4
# inspection              4
# Train's                 4
# out                     4
# water                   4
# Demonstrations          4
# Damage                  4
# Fulton                  4
# Automatic               4
# Wires                   4
# Malfunctions            4
# Cables                  4
# J'Ouvert                4
# Years                   4
# Fatally                 4
# Conductor               4
# Malfunctioning          4
# Construction            4
# testing                 4
# Assitance               4
# PROBLEMS                4
# Rails                   4
# SIck                    4
# And                     4
# Swtich                  4
# Edison                  4
# Rehabilitation          4
# Outages                 4
# Tracks.                 4
# wait                    4
# Down                    4
# Trans                   4
# Vacuum                  3
# Icy                     3
# Investigatiion          3
# Train.                  3
# Cars                    3
# TRACK                   3
# onto                    3
# Transfer                3
# Safety                  3
# Failures                3
# platform                3
# Investigation.          3
# Malfunctiom             3
# E                       3
# fell                    3
# Suspension              3
# MANG                    3
# Department              3
# customers               3
# Paving                  3
# fire                    3
# yard                    3
# Boarding                3
# Bicycle                 3
# damage                  3
# Automatically           3
# Electronic              3
# Parkway                 3
# MAINTENANCE             3
# 149                     3
# Communications          3
# Passenger.              3
# Stuck                   3
# SIgnal                  3
# Single                  3
# Pelham                  3
# was                     3
# Removing                3
# AND                     3
# Concourse               3
# Traffic                 3
# Count                   3
# TRains                  3
# Activity.               3
# Grand                   3
# Filler                  3
# authorized              3
# Unurly                  3
# change                  3
# codition                3
# cancellation            3
# Mechnical               3
# MVM                     3
# Overcrowding            3
# building                3
# Presidential            2
# Fillers                 2
# Inestigation            2
# Onto                    2
# Request                 2
# Disruptive.             2
# Isolation               2
# signaling               2
# dark                    2
# Suitcase                2
# Arrival                 2
# Av                      2
# tracks.                 2
# Reported                2
# stalled                 2
# Borough                 2
# MANh                    2
# Hold                    2
# Park                    2
# Unplanned               2
# andn                    2
# Central                 2
# F                       2
# Member                  2
# Disinsectization        2
# communication           2
# Car.                    2
# PLAN                    2
# S                       2
# Resumed                 2
# Prepare                 2
# SWITCH                  2
# Verizon                 2
# Storage                 2
# Troubles                2
# help                    2
# rerouted                2
# Transactions            2
# sickPassenger           2
# conditon                2
# M                       2
# Isolate                 2
# Obstruction             2
# AM                      2
# Responding              2
# Riding                  2
# Assistanace             2
# because                 2
# CUstomer                2
# Investigtion            2
# Busses                  2
# Structual               2
# Outage.                 2
# Southern                2
# Held                    2
# Animal                  2
# Stall                   2
# Unavailable             2
# inviestigation          2
# TrainS                  2
# into                    2
# Capture                 2
# Event                   2
# branch                  2
# up                      2
# Accident                2
# Westchester             2
# sickCustomer            2
# Picking                 2
# North                   2
# AC                      2
# Move                    2
# inclement               2
# Condtion                2
# Operation               2
# MECHANICAL              2
# Altercation             2
# FASTRACK                2
# Tiffany                 2
# Vehicle                 2
# J'ouvert                2
# Surge                   2
# maintrainence           2
# assitance               2
# Blvd                    2
# Aboard                  2
# Dense                   2
# Carnival                2
# outage                  2
# passengers              2
# Fog                     2
# Data                    2
# Activtiy                2
# Bound                   2
# inspections             2
# Stroller                2
# nd                      2
# Investigate             2
# Bed                     2
# Back                    2
# station                 2
# Equipment.              2
# Hall                    2
# powers                  2
# interior                2
# Fell                    2
# 96                      2
# line                    2
# Unuathorized            2
# Visit                   2
# 167                     2
# Crew                    2
# Replacing               2
# Invest                  2
# malfunction             2
# Place                   2
# TRAIN                   2
# Bypassed                2
# 14                      2
# moving                  2
# Acivity                 1
# being                   1
# Service.                1
# Maintenances            1
# July                    1
# Simpson                 1
# Mon                     1
# Upgrandes               1
# Delay                   1
# Stop                    1
# rains                   1
# Incidet                 1
# EMD                     1
# entering                1
# Problem.                1
# Macy's                  1
# failure                 1
# Disr                    1
# Wide                    1
# Conditioin              1
# broken                  1
# pLAN                    1
# Repairs.                1
# `                       1
# CANCELLATION            1
# Updated                 1
# Break.                  1
# Windows                 1
# Canceled                1
# Sat                     1
# Requested               1
# Source                  1
# Oct                     1
# Incdient                1
# Pocket                  1
# Waits                   1
# Slower                  1
# Broandway               1
# 15                      1
# PRoblems                1
# hanging                 1
# restrictions            1
# Nassau                  1
# Resicual                1
# Inpsections             1
# Resuming                1
# window                  1
# Maintenan               1
# Poss                    1
# #                       1
# Mechaincal              1
# bkY                     1
# network                 1
# 12                      1
# Firework                1
# Advisory                1
# 50                      1
# Late                    1
# Night                   1
# For                     1
# related                 1
# Atty                    1
# Fourth                  1
# Disruption              1
# Clark                   1
# Inspect                 1
# Assault                 1
# 17                      1
# wires                   1
# dtype: int64

# %%
len(wc)
# Out:
# 597

# %%
date_range = pd.date_range(start='01/01/2010 00:00:00', end='10/01/2021 00:00:00', freq='1H')
model_df = pd.DataFrame(index=date_range, columns=['2_delayed', 'irt_delayed', 'cause(s)', 'station(s)',
                                                   'cross-station','rush_hour','planned_service',
                                                   'weather', 'n/b_delay', 's/b_delay', 'borough'])
model_df
# Out:
#                     2_delayed irt_delayed cause(s) station(s) cross-station  \
# 2010-01-01 00:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 01:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 02:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 03:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 04:00:00       NaN         NaN      NaN        NaN           NaN
# ...                       ...         ...      ...        ...           ...
# 2021-09-30 20:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 21:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 22:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 23:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-10-01 00:00:00       NaN         NaN      NaN        NaN           NaN
#
#                     rush_hour planned_service weather n/b_delay s/b_delay  \
# 2010-01-01 00:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 01:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 02:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 03:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 04:00:00       NaN             NaN     NaN       NaN       NaN
# ...                       ...             ...     ...       ...       ...
# 2021-09-30 20:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 21:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 22:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 23:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-10-01 00:00:00       NaN             NaN     NaN       NaN       NaN
#
#                     borough
# 2010-01-01 00:00:00     NaN
# 2010-01-01 01:00:00     NaN
# 2010-01-01 02:00:00     NaN
# 2010-01-01 03:00:00     NaN
# 2010-01-01 04:00:00     NaN
# ...                     ...
# 2021-09-30 20:00:00     NaN
# 2021-09-30 21:00:00     NaN
# 2021-09-30 22:00:00     NaN
# 2021-09-30 23:00:00     NaN
# 2021-10-01 00:00:00     NaN
#
# [102985 rows x 11 columns]

# %%
import datetime as dt

# %%
df2
# Out:
#                      date  \
# 2     2021-09-30 21:34:00
# 3     2021-09-30 21:28:00
# 4     2021-09-30 19:14:00
# 5     2021-09-30 19:10:00
# 7     2021-09-30 18:48:00
# ...                   ...
# 67467 2010-01-06 08:45:00
# 67468 2010-01-06 07:41:00
# 67471 2010-01-05 18:08:00
# 67477 2010-01-01 10:56:00
# 67478 2010-01-01 09:55:00
#
#                                                     subject  \
# 2                            Update : BX   2 Train   Delays
# 3                                     BX   2 Train   Delays
# 4                            Update : BX   2 Train   Delays
# 5                                     BX   2 Train   Delays
# 7                   Update : BX   2 Train   Trains Rerouted
# ...                                                     ...
# 67467   UPDATED : BX    2 & 5 Trains   Police Investigation
# 67468             BX    2 & 5 Trains   Police Investigation
# 67471             1 and 2 Lines - Late Night Service Change
# 67477  UPDATED : MANH   2 & 3 trains   Police Investigation
# 67478            MANH   2 & 3 trains   Police Investigation
#
#                                                                                                                                         message
# 2                                 2 trains are proceeding with delays after our crews moved a train that had its brakes activated at Nereid Av.
# 3                         2 trains are delayed in both directions while our crews investigate why a train's brakes were activated at Nereid Av.
# 4                                       Southbound 2 trains are proceeding after we moved a train that had its brakes activated at Allerton Av.
# 5                                      Southbound 2 trains are delayed while we investigate why a train's brakes were activated at Allerton Av.
# 7                          Wakefield-bound 2 trains have resumed stopping at bx Park East after we helped an injured passenger at that station.
# ...                                                                                                                                         ...
# 67467                                                                                    2 & 5 train service has resumed with residual delays.
# 67468  Both directions 2 & 5 trains bypassing 3rd Av-149th St. Due to nypd investigation at 3rd Ave-149th st. Visit www.mta.info for details.
# 67471                    Downtown 1 and 2 trains run express from 34 St-Penn Station to Chambers St Late Night Jan 7 12 :01 AM to 5 AM Tuesday
# 67477                                                                                     2 & 3 train service has resumed with residual delays.
# 67478    Selected BK-bound 2 & 3 trains terminate at various stations. Due to nypd investigation at Houston St. Visit www.mta.info for details.
#
# [22563 rows x 3 columns]

# %%
df2['date'] = df2['date'].dt.round('60min')
# Out:
# <ipython-input-15-d91481cfd004>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = df2['date'].dt.round('60min')

# %%
df_irt['date'] = df_irt['date'].dt.round('60min')
# Out:
# <ipython-input-30-6b7537b31764>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_irt['date'] = df_irt['date'].dt.round('60min')

# %%
df2.set_index('date', inplace=True)

# %%
df_irt.set_index('date',inplace=True)

# %%
df2
# Out:
#                                                                   subject  \
# date
# 2021-09-30 22:00:00                        Update : BX   2 Train   Delays
# 2021-09-30 21:00:00                                 BX   2 Train   Delays
# 2021-09-30 19:00:00                        Update : BX   2 Train   Delays
# 2021-09-30 19:00:00                                 BX   2 Train   Delays
# 2021-09-30 19:00:00               Update : BX   2 Train   Trains Rerouted
# ...                                                                   ...
# 2010-01-06 09:00:00   UPDATED : BX    2 & 5 Trains   Police Investigation
# 2010-01-06 08:00:00             BX    2 & 5 Trains   Police Investigation
# 2010-01-05 18:00:00             1 and 2 Lines - Late Night Service Change
# 2010-01-01 11:00:00  UPDATED : MANH   2 & 3 trains   Police Investigation
# 2010-01-01 10:00:00            MANH   2 & 3 trains   Police Investigation
#
#                                                                                                                                                       message
# date
# 2021-09-30 22:00:00                             2 trains are proceeding with delays after our crews moved a train that had its brakes activated at Nereid Av.
# 2021-09-30 21:00:00                     2 trains are delayed in both directions while our crews investigate why a train's brakes were activated at Nereid Av.
# 2021-09-30 19:00:00                                   Southbound 2 trains are proceeding after we moved a train that had its brakes activated at Allerton Av.
# 2021-09-30 19:00:00                                  Southbound 2 trains are delayed while we investigate why a train's brakes were activated at Allerton Av.
# 2021-09-30 19:00:00                      Wakefield-bound 2 trains have resumed stopping at bx Park East after we helped an injured passenger at that station.
# ...                                                                                                                                                       ...
# 2010-01-06 09:00:00                                                                                    2 & 5 train service has resumed with residual delays.
# 2010-01-06 08:00:00  Both directions 2 & 5 trains bypassing 3rd Av-149th St. Due to nypd investigation at 3rd Ave-149th st. Visit www.mta.info for details.
# 2010-01-05 18:00:00                    Downtown 1 and 2 trains run express from 34 St-Penn Station to Chambers St Late Night Jan 7 12 :01 AM to 5 AM Tuesday
# 2010-01-01 11:00:00                                                                                     2 & 3 train service has resumed with residual delays.
# 2010-01-01 10:00:00    Selected BK-bound 2 & 3 trains terminate at various stations. Due to nypd investigation at Houston St. Visit www.mta.info for details.
#
# [22563 rows x 2 columns]

# %%
df2.to_csv('df2.csv')

# %%
model_df
# Out:
#                     2_delayed irt_delayed cause(s) station(s) cross-station  \
# 2010-01-01 00:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 01:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 02:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 03:00:00       NaN         NaN      NaN        NaN           NaN
# 2010-01-01 04:00:00       NaN         NaN      NaN        NaN           NaN
# ...                       ...         ...      ...        ...           ...
# 2021-09-30 20:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 21:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 22:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-09-30 23:00:00       NaN         NaN      NaN        NaN           NaN
# 2021-10-01 00:00:00       NaN         NaN      NaN        NaN           NaN
#
#                     rush_hour planned_service weather n/b_delay s/b_delay  \
# 2010-01-01 00:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 01:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 02:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 03:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 04:00:00       NaN             NaN     NaN       NaN       NaN
# ...                       ...             ...     ...       ...       ...
# 2021-09-30 20:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 21:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 22:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 23:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-10-01 00:00:00       NaN             NaN     NaN       NaN       NaN
#
#                     borough
# 2010-01-01 00:00:00     NaN
# 2010-01-01 01:00:00     NaN
# 2010-01-01 02:00:00     NaN
# 2010-01-01 03:00:00     NaN
# 2010-01-01 04:00:00     NaN
# ...                     ...
# 2021-09-30 20:00:00     NaN
# 2021-09-30 21:00:00     NaN
# 2021-09-30 22:00:00     NaN
# 2021-09-30 23:00:00     NaN
# 2021-10-01 00:00:00     NaN
#
# [102985 rows x 11 columns]

# %%
dates_2 = pd.Series(df2.index)

# %%
dates_2
# Out:
# 0       2021-09-30 22:00:00
# 1       2021-09-30 21:00:00
# 2       2021-09-30 19:00:00
# 3       2021-09-30 19:00:00
# 4       2021-09-30 19:00:00
#                 ...
# 22558   2010-01-06 09:00:00
# 22559   2010-01-06 08:00:00
# 22560   2010-01-05 18:00:00
# 22561   2010-01-01 11:00:00
# 22562   2010-01-01 10:00:00
# Name: date, Length: 22563, dtype: datetime64[ns]

# %%
list_of_datetimes = [dates_2, dates_2 + pd.Timedelta('1 hour'), dates_2 + pd.Timedelta('2 hour')]

# %%
len(list_of_datetimes[2].unique())
# Out:
# 13419

# %%
date_2 = dates_2.unique()
hour_plus_one = pd.Series(list_of_datetimes[1].unique())
hour_plus_two = pd.Series(list_of_datetimes[2].unique())

# %%
len(dates_2.unique())
# Out:
# 13419

# %%
model_df['2_delayed'].fillna(0, inplace=True)
model_df['irt_delayed'].fillna(0, inplace=True)

# %%
model_df
# Out:
#                      2_delayed  irt_delayed cause(s) station(s) cross-station  \
# 2010-01-01 00:00:00          0            0      NaN        NaN           NaN
# 2010-01-01 01:00:00          0            0      NaN        NaN           NaN
# 2010-01-01 02:00:00          0            0      NaN        NaN           NaN
# 2010-01-01 03:00:00          0            0      NaN        NaN           NaN
# 2010-01-01 04:00:00          0            0      NaN        NaN           NaN
# ...                        ...          ...      ...        ...           ...
# 2021-09-30 20:00:00          0            0      NaN        NaN           NaN
# 2021-09-30 21:00:00          0            0      NaN        NaN           NaN
# 2021-09-30 22:00:00          0            0      NaN        NaN           NaN
# 2021-09-30 23:00:00          0            0      NaN        NaN           NaN
# 2021-10-01 00:00:00          0            0      NaN        NaN           NaN
#
#                     rush_hour planned_service weather n/b_delay s/b_delay  \
# 2010-01-01 00:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 01:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 02:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 03:00:00       NaN             NaN     NaN       NaN       NaN
# 2010-01-01 04:00:00       NaN             NaN     NaN       NaN       NaN
# ...                       ...             ...     ...       ...       ...
# 2021-09-30 20:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 21:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 22:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-09-30 23:00:00       NaN             NaN     NaN       NaN       NaN
# 2021-10-01 00:00:00       NaN             NaN     NaN       NaN       NaN
#
#                     borough
# 2010-01-01 00:00:00     NaN
# 2010-01-01 01:00:00     NaN
# 2010-01-01 02:00:00     NaN
# 2010-01-01 03:00:00     NaN
# 2010-01-01 04:00:00     NaN
# ...                     ...
# 2021-09-30 20:00:00     NaN
# 2021-09-30 21:00:00     NaN
# 2021-09-30 22:00:00     NaN
# 2021-09-30 23:00:00     NaN
# 2021-10-01 00:00:00     NaN
#
# [102985 rows x 11 columns]

# %%
# !pwd
# Out:
# /c/users/sethk/documents/flatiron/phase5_capstone/mta/mta_service_delays/data_cleaning

# %%
model_df.to_csv('model.csv')

# %%
irt_normal = dates_irt.unique()
irt_plus_one = irt_datetimes[1].unique()
irt_plus_two = irt_datetimes[2].unique()

# %%
dates_irt = pd.Series(df_irt.index)
irt_datetimes = [dates_irt, dates_irt + pd.Timedelta('1 hour'), dates_irt + pd.Timedelta('2 hour')]

# %%
irt_normal = dates_irt.unique()
irt_plus_one = irt_datetimes[1].unique()
irt_plus_two = irt_datetimes[2].unique()

# %%
for date in model_df.index:
    for num in irt_normal:
        if num == date:
            model_df['irt_delayed'] += 1
        else:
            for num in irt_plus_one:
                if num == date:
                    model_df['irt_delayed'] += 1
                else:
                    for num in irt_plus_two:
                        if num == date:
                            model_df['irt_delayed'] += 1
                        else:
                            model_df['irt_delayed'] += 0

# %%
with open('model.pkl', 'wb') as f:
    pkl.dump(model_df, f)
