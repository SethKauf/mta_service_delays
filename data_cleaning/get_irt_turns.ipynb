# %%
import pandas as pd
import pickle as pkl
pd.set_option('display.max_rows',1000)

# %%
stations = ['103 ST', '103 ST-CORONA', '110 ST', '110 ST-CATHEDRL', '110 ST-CPN', '111 ST', '116 ST', '116 ST-COLUMBIA',
            '125 ST', '135 ST', '137 ST CITY COL', '137 ST-CITY COL', '138 ST-3 AVE', '138 ST-GR CONC', '138/GRAND CONC',
            '14 ST', '14 ST-6 AVE', '14 ST-UNION SQ', '145 ST', '148 ST-LENOX', '149 ST-3 AVE', '149 ST-GR CONC',
            '149/GRAND CONC', '14TH STREET', '157 ST', '161 ST-YANKEE', '161/YANKEE STAD', '167 ST', '168 ST',
            '168 ST-BROADWAY', '170 ST', '174 ST', '176 ST', '18 ST', '181 ST', '183 ST', '191 ST', '207 ST', '215 ST',
            '219 ST', '225 ST', '23 ST', '231 ST', '233 ST', '238 ST', '242 ST', '28 ST', '3 AV 138 ST', '3 AV-149 ST',
             '33 ST', '33 ST-RAWSON ST', '33 ST/RAWSON ST', '34 ST-HUDSON YD', '34 ST-PENN STA', '40 ST LOWERY ST',
            '40 ST-LOWERY ST', '42 ST-BRYANT PK', '42 ST-GRD CNTRL', '42 ST-PA BUS TE', '42 ST-PORT AUTH', '42 ST-TIMES SQ',
             '46 ST BLISS ST', '46 ST-BLISS ST', '5 AVE', '5 AVE-BRYANT PK', '50 ST', '51 ST', '52 ST', '52 ST-LINCOLN',
            '59 ST', '59 ST COLUMBUS', '59 ST-COLUMBUS', '6 AV', '6 AVE', '61 ST WOODSIDE', '61 ST/WOODSIDE', '66 ST-LINCOLN',
            '68ST-HUNTER CO', '68ST-HUNTER COL', '69 ST', '69 ST-FISK AVE', '72 ST', '74 ST-BROADWAY', '77 ST', '79 ST',
            '82 ST-JACKSON H', '86 ST', '90 ST-ELMHURST', '96 ST', '9TH STREET', 'ALLERTON AV', 'ALLERTON AVE', 'ASTOR PL',
            'ASTOR PLACE', 'ATL AV-BARCLAY', "B'WAY-LAFAYETTE", 'BARCLAYS CENTER', 'BAYCHESTER AV', 'BAYCHESTER AVE',
            'BEACH 105 ST', 'BEACH 90 ST', 'BEACH 98 ST', 'BEDFORD PARK BL', 'BEDFORD PK BLVD', 'BERGEN ST', 'BEVERLY RD',
             'BEVERLY ROAD', 'BLEECKER ST', 'BOROUGH HALL', 'BOROUGH HALL/CT', 'BOTANIC GARDEN', 'BOWLING GREEN',
            'BROAD CHANNEL', 'BROADWAY/LAFAY', 'BRONX PARK EAST', 'BROOK AV', 'BROOK AVE', 'BROOKLYN BRIDGE',
            'BUHRE AV', 'BUHRE AVE', 'BURKE AV', 'BURKE AVE', 'BURNSIDE AV', 'BURNSIDE AVE', 'CANAL ST', 'CASTLE HILL AV',
            'CASTLE HILL AVE', 'CATHEDRAL PKWY', 'CENTRAL PK N110', 'CHAMBERS ST', 'CHRISTOPHER ST', 'CHURCH AV', 'CHURCH AVE',
            'CITY / BUS', 'CLARK ST', 'CORTLANDT ST', 'COURT SQ', 'CROWN HTS-UTICA', 'CYPRESS AV', 'CYPRESS AVE',
            'DYCKMAN ST', 'DYRE AVE', 'E 143 ST', "E 143/ST MARY'S", 'E 149 ST', 'E 177 ST-PARKCH', 'E 180 ST', 'E TREMONT AVE',
            'EASTCHSTER/DYRE', 'EASTERN PKWY', 'EASTN PKWY-MUSM', 'ELDER AV', 'ELDER AVE', 'EXCHANGE PLACE',
            'FLATBUSH AV-B.C', 'FLATBUSH AVE', 'FLUSHING-MAIN', 'FORDHAM RD', 'FORDHAM ROAD', 'FRANKLIN AV',
            'FRANKLIN AVE', 'FRANKLIN ST', 'FREEMAN ST', 'FULTON ST', 'GRAND ARMY PLAZ', 'GRD CNTRL-42 ST', 'GROVE STREET',
             'GUN HILL RD', 'GUN HILL ROAD', 'HARLEM 148 ST', 'HARRISON', 'HOUSTON ST', 'HOYT ST', 'HUNTERS PT AV',
            'HUNTERS PT AVE', 'HUNTS POINT AV', 'HUNTS POINT AVE', 'INTERVALE AV', 'INTERVALE-163', 'JACKSON AV',
            'JACKSON AVE', 'JKSN HT-ROOSVLT', 'JOURNAL SQUARE', 'JUNCTION BLVD', 'JUNIUS ST', 'KINGSBRIDGE RD',
            'KINGSTON AV', 'KINGSTON AVE', 'LACKAWANNA', 'LEXINGTON AV/53', 'LEXINGTON AVE', 'LEXINGTON-53 ST',
            'LONGWOOD AV', 'LONGWOOD AVE', 'MAIN ST', 'MARBLE HILL-225', 'METS-WILLETS PT', 'MIDDLETOWN RD','MIDDLETOWN ROAD',
             'MORISN AV/SNDVW', 'MORRIS PARK', 'MORRISON AVE', 'MOSHOLU PARKWAY', 'MOSHOLU PKWY', 'MT EDEN AV',
            'MT EDEN AVE', 'NEREID AV', 'NEREID AVE', 'NEVINS ST', 'NEW LOTS AV', 'NEW LOTS AVE', 'NEWARK BM BW',
            'NEWARK C', 'NEWARK HM HE', 'NEWARK HW BMEBE', 'NEWKIRK AV', 'NEWKIRK AVE', 'NOSTRAND AV', 'NOSTRAND AVE',
            'ORCHARD BEACH', 'PARK PLACE', 'PARKCHESTER', 'PATH NEW WTC', 'PATH WTC', 'PATH WTC 2', 'PAVONIA/NEWPORT',
            'PELHAM BAY PARK', 'PELHAM PARKWAY', 'PELHAM PKWY', 'PENNSYLVANIA AV', 'PRESIDENT ST', 'PROSPECT AV', 'PROSPECT AVE',
            'PROSPECT PARK', 'QUEENSBORO PLZ', 'RECTOR ST', 'ROCKAWAY AV', 'ROCKAWAY AVE', 'ROCKAWAY PARK B', 'ROCKAWAY PK 116',
             'ROOSEVELT AVE', 'SARATOGA AV', 'SARATOGA AVE', 'SIMPSON ST', 'SOUTH FERRY', 'SPRING ST', 'ST LAWRENCE AV',
            'ST LAWRENCE AVE', 'ST. GEORGE', 'STERLING ST', 'SUTTER AV-RUTLD', 'SUTTER AVE', 'THIRTY ST', 'THIRTY THIRD ST',
            'TIMES SQ-42 ST', 'TOMPKINSVILLE', 'TWENTY THIRD ST', 'V.CORTLANDT PK', 'VAN SICLEN AV', 'VAN SICLEN AVE',
            'VERNON-JACKSON', 'VERNON/JACKSON', 'WAKEFIELD-241', 'WAKEFIELD/241', 'WALL ST', 'WEST FARMS SQ', 'WESTCHESTER SQ',
             'WHITEHALL S-FRY', 'WHITEHALL ST', 'WHITLOCK AV', 'WHITLOCK AVE', 'WINTHROP ST', 'WOODLAWN', 'WOODLAWN ROAD',
            'WORLD TRADE CTR', 'WTC-CORTLANDT', 'ZEREGA AV', 'ZEREGA AVE']

# %%
with open('../get_data/turnstiles.pkl','rb') as f:
    df = pkl.load(f)

# %%
df = df.loc[~(df['division']=='PTH')&~(df['division']=='SRT')&~(df['division']=='RIT')]
df
# Out:
#          control_area  unit       scp          station train_lines division  \
# 0                A060  R001  00-00-00     WHITEHALL ST          R1      BMT
# 1                A060  R001  00-00-00     WHITEHALL ST          R1      BMT
# 2                A060  R001  00-00-00     WHITEHALL ST          R1      BMT
# 3                A060  R001  00-00-00     WHITEHALL ST          R1      BMT
# 4                A060  R001  00-00-00     WHITEHALL ST          R1      BMT
# ...               ...   ...       ...              ...         ...      ...
# 72804707         R730  R431  00-00-04  EASTCHSTER/DYRE           5      IRT
# 72804708         R730  R431  00-00-04  EASTCHSTER/DYRE           5      IRT
# 72804709         R730  R431  00-00-04  EASTCHSTER/DYRE           5      IRT
# 72804710         R730  R431  00-00-04  EASTCHSTER/DYRE           5      IRT
# 72804711         R730  R431  00-00-04  EASTCHSTER/DYRE           5      IRT
#
# ...

# %%
check = sorted(df['station'].value_counts().index)

# %%
len(check)
# Out:
# 549

# %%
df.drop(['control_area','scp','desc','unit'],axis=1,inplace=True)
df.rename({'datetime':'date','train_lines':'lines'},axis=1,inplace=True)

# %%
irt_df = df.loc[df['lines'].str.contains('1|2|3|4|5|6|7|S')]

# %%
irt_df
# Out:
#                   station lines division     entries       exits  \
# 0            WHITEHALL ST    R1      BMT      805439     1141080
# 1            WHITEHALL ST    R1      BMT      805459     1141141
# 2            WHITEHALL ST    R1      BMT      805589     1141257
# 3            WHITEHALL ST    R1      BMT      805834     1141512
# 4            WHITEHALL ST    R1      BMT      806150     1141903
# ...                   ...   ...      ...         ...         ...
# 72804707  EASTCHSTER/DYRE     5      IRT  1559793580  1728258395
# 72804708  EASTCHSTER/DYRE     5      IRT  1559793463  1728258434
# 72804709  EASTCHSTER/DYRE     5      IRT  1559793445  1728258446
# 72804710  EASTCHSTER/DYRE     5      IRT  1559793395  1728258511
# 72804711  EASTCHSTER/DYRE     5      IRT  1559793360  1728258559
#
#                         date
# 0        2014-10-11 01:00:00
# 1        2014-10-11 05:00:00
# 2        2014-10-11 09:00:00
# 3        2014-10-11 13:00:00
# 4        2014-10-11 17:00:00
# ...

# %%
with open('data/turnstile_irt.pkl','wb') as f:
    pkl.dump(irt_df, f)

# %%
irt_df.loc[irt_df['station']=="5 AVE"]
# Out:
#          station  lines division  entries    exits                date
# 12066826   5 AVE  7BDFM      IRT   295613  2017798 2015-12-26 03:00:00
# 12066827   5 AVE  7BDFM      IRT   295615  2017861 2015-12-26 07:00:00
# 12066828   5 AVE  7BDFM      IRT   295635  2018191 2015-12-26 11:00:00
# 12066829   5 AVE  7BDFM      IRT   295732  2018975 2015-12-26 15:00:00
# 12066830   5 AVE  7BDFM      IRT   295993  2019767 2015-12-26 19:00:00
# ...          ...    ...      ...      ...      ...                 ...
# 72782225   5 AVE  7BDFM      IRT   397236     1555 2021-10-08 04:00:00
# 72782226   5 AVE  7BDFM      IRT   397253     1589 2021-10-08 08:00:00
# 72782227   5 AVE  7BDFM      IRT   397364     1697 2021-10-08 12:00:00
# 72782228   5 AVE  7BDFM      IRT   397640     1842 2021-10-08 16:00:00
# 72782229   5 AVE  7BDFM      IRT   398113     1957 2021-10-08 20:00:00
#
# [127546 rows x 6 columns]

# %%
sorted(df['station'].value_counts().index)
# Out:
# ['1 AV',
#  '1 AVE',
#  '103 ST',
#  '103 ST-CORONA',
#  '104 ST',
#  '110 ST',
#  '110 ST-CATHEDRL',
#  '110 ST-CPN',
#  '111 ST',
#  '116 ST',
#  '116 ST-COLUMBIA',
#  '121 ST',
#  '125 ST',
#  '135 ST',
#  '137 ST CITY COL',
#  '137 ST-CITY COL',
#  '138 ST-3 AVE',
#  '138 ST-GR CONC',
#  '138/GRAND CONC',
#  '14 ST',
#  '14 ST-6 AVE',
#  '14 ST-UNION SQ',
#  '145 ST',
#  '148 ST-LENOX',
#  '149 ST-3 AVE',
#  '149 ST-GR CONC',
#  '149/GRAND CONC',
#  '15 ST-PROSPECT',
#  '155 ST',
#  '157 ST',
#  '161 ST-YANKEE',
#  '161/YANKEE STAD',
#  '163 ST-AMSTERDM',
#  '167 ST',
#  '168 ST',
#  '168 ST-BROADWAY',
#  '169 ST',
#  '170 ST',
#  '174 ST',
#  '174-175 ST',
#  '174-175 STS',
#  '175 ST',
#  '176 ST',
#  '18 AV',
#  '18 AVE',
#  '18 ST',
#  '181 ST',
#  '182-183 ST',
#  '182-183 STS',
#  '183 ST',
#  '190 ST',
#  '191 ST',
#  '2 AV',
#  '2 AVE',
#  '20 AV',
#  '20 AVE',
#  '207 ST',
#  '21 ST',
#  '21 ST-QNSBRIDGE',
#  '215 ST',
#  '219 ST',
#  '22 AVE-BAY PKY',
#  '225 ST',
# ...

# %%
stations = ['103 ST', '103 ST-CORONA', '110 ST', '110 ST-CATHEDRL', '110 ST-CPN', '111 ST', '116 ST', '116 ST-COLUMBIA',
            '125 ST', '135 ST', '137 ST CITY COL', '137 ST-CITY COL', '138 ST-3 AVE', '138 ST-GR CONC', '138/GRAND CONC',
            '14 ST', '14 ST-6 AVE', '14 ST-UNION SQ', '145 ST', '148 ST-LENOX', '149 ST-3 AVE', '149 ST-GR CONC',
            '149/GRAND CONC', '14TH STREET', '157 ST', '161 ST-YANKEE', '161/YANKEE STAD', '167 ST', '168 ST',
            '168 ST-BROADWAY', '170 ST', '174 ST', '176 ST', '18 ST', '181 ST', '183 ST', '191 ST', '207 ST', '215 ST',
            '219 ST', '225 ST', '23 ST', '231 ST', '233 ST', '238 ST', '242 ST', '28 ST', '3 AV 138 ST', '3 AV-149 ST',
             '33 ST', '33 ST-RAWSON ST', '33 ST/RAWSON ST', '34 ST-HUDSON YD', '34 ST-PENN STA', '40 ST LOWERY ST',
            '40 ST-LOWERY ST', '42 ST-BRYANT PK', '42 ST-GRD CNTRL',
             '46 ST BLISS ST', '46 ST-BLISS ST', '5 AVE', '5 AVE-BRYANT PK', '50 ST', '51 ST', '52 ST', '52 ST-LINCOLN',
            '59 ST', '59 ST COLUMBUS', '59 ST-COLUMBUS', '6 AV', '6 AVE', '61 ST WOODSIDE', '61 ST/WOODSIDE', '66 ST-LINCOLN',
            '68ST-HUNTER CO', '68ST-HUNTER COL', '69 ST', '69 ST-FISK AVE', '72 ST', '74 ST-BROADWAY', '77 ST', '79 ST',
            '82 ST-JACKSON H', '86 ST', '90 ST-ELMHURST', '96 ST', '9TH STREET', 'ALLERTON AV', 'ALLERTON AVE', 'ASTOR PL',
            'ASTOR PLACE', 'ATL AV-BARCLAY', "B'WAY-LAFAYETTE", 'BARCLAYS CENTER', 'BAYCHESTER AV', 'BAYCHESTER AVE',
            'BEACH 105 ST', 'BEACH 90 ST', 'BEACH 98 ST', 'BEDFORD PARK BL', 'BEDFORD PK BLVD', 'BERGEN ST', 'BEVERLY RD',
             'BEVERLY ROAD', 'BLEECKER ST', 'BOROUGH HALL', 'BOROUGH HALL/CT', 'BOTANIC GARDEN', 'BOWLING GREEN',
            'BROAD CHANNEL', 'BROADWAY/LAFAY', 'BRONX PARK EAST', 'BROOK AV', 'BROOK AVE', 'BROOKLYN BRIDGE',
            'BUHRE AV', 'BUHRE AVE', 'BURKE AV', 'BURKE AVE', 'BURNSIDE AV', 'BURNSIDE AVE', 'CANAL ST', 'CASTLE HILL AV',
            'CASTLE HILL AVE', 'CATHEDRAL PKWY', 'CENTRAL PK N110', 'CHAMBERS ST', 'CHRISTOPHER ST', 'CHURCH AV', 'CHURCH AVE',
            'CITY / BUS', 'CLARK ST', 'CORTLANDT ST', 'COURT SQ', 'CROWN HTS-UTICA', 'CYPRESS AV', 'CYPRESS AVE',
            'DYCKMAN ST', 'DYRE AVE', 'E 143 ST', "E 143/ST MARY'S", 'E 149 ST', 'E 177 ST-PARKCH', 'E 180 ST', 'E TREMONT AVE',
            'EASTCHSTER/DYRE', 'EASTERN PKWY', 'EASTN PKWY-MUSM', 'ELDER AV', 'ELDER AVE', 'EXCHANGE PLACE',
            'FLATBUSH AV-B.C', 'FLATBUSH AVE', 'FLUSHING-MAIN', 'FORDHAM RD', 'FORDHAM ROAD', 'FRANKLIN AV',
            'FRANKLIN AVE', 'FRANKLIN ST', 'FREEMAN ST', 'FULTON ST', 'GRAND ARMY PLAZ', 'GRD CNTRL-42 ST', 'GROVE STREET',
             'GUN HILL RD', 'GUN HILL ROAD', 'HARLEM 148 ST', 'HARRISON', 'HOUSTON ST', 'HOYT ST', 'HUNTERS PT AV',
            'HUNTERS PT AVE', 'HUNTS POINT AV', 'HUNTS POINT AVE', 'INTERVALE AV', 'INTERVALE-163', 'JACKSON AV',
            'JACKSON AVE', 'JKSN HT-ROOSVLT', 'JOURNAL SQUARE', 'JUNCTION BLVD', 'JUNIUS ST', 'KINGSBRIDGE RD',
            'KINGSTON AV', 'KINGSTON AVE', 'LACKAWANNA', 'LEXINGTON AV/53', 'LEXINGTON AVE', 'LEXINGTON-53 ST',
            'LONGWOOD AV', 'LONGWOOD AVE', 'MAIN ST', 'MARBLE HILL-225', 'METS-WILLETS PT', 'MIDDLETOWN RD','MIDDLETOWN ROAD',
             'MORISN AV/SNDVW', 'MORRIS PARK', 'MORRISON AVE', 'MOSHOLU PARKWAY', 'MOSHOLU PKWY', 'MT EDEN AV',
            'MT EDEN AVE', 'NEREID AV', 'NEREID AVE', 'NEVINS ST', 'NEW LOTS AV', 'NEW LOTS AVE', 'NEWARK BM BW',
            'NEWARK C', 'NEWARK HM HE', 'NEWARK HW BMEBE', 'NEWKIRK AV', 'NEWKIRK AVE', 'NOSTRAND AV', 'NOSTRAND AVE',
            'ORCHARD BEACH', 'PARK PLACE', 'PARKCHESTER', 'PATH NEW WTC', 'PATH WTC', 'PATH WTC 2', 'PAVONIA/NEWPORT',
            'PELHAM BAY PARK', 'PELHAM PARKWAY', 'PELHAM PKWY', 'PENNSYLVANIA AV', 'PRESIDENT ST', 'PROSPECT AV', 'PROSPECT AVE',
            'PROSPECT PARK', 'QUEENSBORO PLZ', 'RECTOR ST', 'ROCKAWAY AV', 'ROCKAWAY AVE', 'ROCKAWAY PARK B', 'ROCKAWAY PK 116',
             'ROOSEVELT AVE', 'SARATOGA AV', 'SARATOGA AVE', 'SIMPSON ST', 'SOUTH FERRY', 'SPRING ST', 'ST LAWRENCE AV',
            'ST LAWRENCE AVE', 'ST. GEORGE', 'STERLING ST', 'SUTTER AV-RUTLD', 'SUTTER AVE', 'THIRTY ST', 'THIRTY THIRD ST',
            'TOMPKINSVILLE', 'TWENTY THIRD ST', 'V.CORTLANDT PK', 'VAN SICLEN AV', 'VAN SICLEN AVE',
            'VERNON-JACKSON', 'VERNON/JACKSON', 'WAKEFIELD-241', 'WAKEFIELD/241', 'WALL ST', 'WEST FARMS SQ', 'WESTCHESTER SQ',
             'WHITEHALL S-FRY', 'WHITEHALL ST', 'WHITLOCK AV', 'WHITLOCK AVE', 'WINTHROP ST', 'WOODLAWN', 'WOODLAWN ROAD',
            'WORLD TRADE CTR', 'WTC-CORTLANDT', 'ZEREGA AV', 'ZEREGA AVE']

# %%
times_sq = df.loc[(df['station']=='42 ST-PORT AUTH')|(df['station']== '42 ST-PA BUS TE')|
                  (df['station']=='42 ST-TIMES SQ')|(df['station']=='TIMES SQ-42 ST')]

# %%
times_sq.set_index('date',inplace=True)

# %%
times_sq['station']='times sq-42 st'
# Out:
# <ipython-input-14-963ac772abcb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   times_sq['station']='times sq-42 st'
